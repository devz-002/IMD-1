# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
input_file_path = '/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/bageswar.txt'

# %%
import csv

# %% [markdown]
# THE ONE THAT WORKS

# %%
import csv

def extract_to_csv(input_file_path, output_directory):
    # Open the input file for reading
    with open(input_file_path, 'r') as input_file:
        # Read all lines from the file
        lines = input_file.readlines()

        # Extract station name from line 12 (assuming the name is between ':' and ',')
        station_name = lines[11].split(':')[1].split(',')[0].strip()

        # Extract CSV headings from line 14
        csv_headings = lines[13].split()

        # Extract data from lines 16 to 84
        data_lines = lines[15:134]

        # Create a CSV file with the extracted data
        output_file_path = f'{output_directory}/{station_name}.csv'
        with open(output_file_path, 'w', newline='') as csv_file:
            csv_writer = csv.writer(csv_file)

            # Write the CSV headings
            csv_writer.writerow(['YEAR', 'MN'] + csv_headings[2:])

            # Write the data to the CSV file
            for data_line in data_lines:
                # Split the line into columns
                columns = data_line.split()

                # Write the relevant data to the CSV file
                csv_writer.writerow(columns[:2] + columns[2:])

    print(f"Data extracted and saved to {output_file_path}")

# Replace 'path/to/your/input.txt' with the actual file path
# Replace 'path/to/your/output_directory' with the desired output directory
extract_to_csv('/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/bageswar.txt', '/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul')
# Out:
# Data extracted and saved to /content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/BAGESWAR.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import csv

def extract_to_csv(input_file_path, output_directory):
    # Open the input file for reading
    with open(input_file_path, 'r') as input_file:
        # Read all lines from the file
        lines = input_file.readlines()

        # Extract station name from line 97 (assuming the name is between ':' and ',')
        station_name = lines[138].split(':')[1].split(',')[0].strip()

        # Extract CSV headings from line 99
        csv_headings = lines[140].split()

        # Extract data from lines 101 to 168
        data_lines = lines[142:271]

        # Create a CSV file with the extracted data
        output_file_path = f'{output_directory}/{station_name}.csv'
        with open(output_file_path, 'w', newline='') as csv_file:
            csv_writer = csv.writer(csv_file)

            # Write the CSV headings
            csv_writer.writerow(['YEAR', 'MN'] + csv_headings[2:])

            # Write the data to the CSV file
            for data_line in data_lines:
                # Split the line into columns
                columns = data_line.split()

                # Write the relevant data to the CSV file
                csv_writer.writerow(columns[:2] + columns[2:])

    print(f"Data extracted and saved to {output_file_path}")

# Replace 'path/to/your/input.txt' with the actual file path
# Replace 'path/to/your/output_directory' with the desired output directory
extract_to_csv('/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/bageswar.txt', '/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul')
# Out:
# Data extracted and saved to /content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/BAGESWAR     (G) (HYDRO) [.csv

# %%
import csv

def extract_to_csv(input_file_path, output_directory):
    # Open the input file for reading
    with open(input_file_path, 'r') as input_file:
        # Read all lines from the file
        lines = input_file.readlines()

        # Extract station name from line 97 (assuming the name is between ':' and ',')
        station_name = lines[351].split(':')[1].split(',')[0].strip()

        # Extract CSV headings from line 99
        csv_headings = lines[353].split()

        # Extract data from lines 101 to 168
        data_lines = lines[355:472]

        # Create a CSV file with the extracted data
        output_file_path = f'{output_directory}/{station_name}.csv'
        with open(output_file_path, 'w', newline='') as csv_file:
            csv_writer = csv.writer(csv_file)

            # Write the CSV headings
            csv_writer.writerow(['YEAR', 'MN'] + csv_headings[2:])

            # Write the data to the CSV file
            for data_line in data_lines:
                # Split the line into columns
                columns = data_line.split()

                # Write the relevant data to the CSV file
                csv_writer.writerow(columns[:2] + columns[2:])

    print(f"Data extracted and saved to {output_file_path}")

# Replace 'path/to/your/input.txt' with the actual file path
# Replace 'path/to/your/output_directory' with the desired output directory
extract_to_csv('/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/bageswar.txt', '/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul')
# Out:
# Data extracted and saved to /content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/GARUR [.csv

# %%
import csv

def extract_to_csv(input_file_path, output_directory):
    # Open the input file for reading
    with open(input_file_path, 'r') as input_file:
        # Read all lines from the file
        lines = input_file.readlines()

        # Extract station name from line 97 (assuming the name is between ':' and ',')
        station_name = lines[534].split(':')[1].split(',')[0].strip()

        # Extract CSV headings from line 99
        csv_headings = lines[536].split()

        # Extract data from lines 101 to 168
        data_lines = lines[538:655]

        # Create a CSV file with the extracted data
        output_file_path = f'{output_directory}/{station_name}.csv'
        with open(output_file_path, 'w', newline='') as csv_file:
            csv_writer = csv.writer(csv_file)

            # Write the CSV headings
            csv_writer.writerow(['YEAR', 'MN'] + csv_headings[2:])

            # Write the data to the CSV file
            for data_line in data_lines:
                # Split the line into columns
                columns = data_line.split()

                # Write the relevant data to the CSV file
                csv_writer.writerow(columns[:2] + columns[2:])

    print(f"Data extracted and saved to {output_file_path}")

# Replace 'path/to/your/input.txt' with the actual file path
# Replace 'path/to/your/output_directory' with the desired output directory
extract_to_csv('/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/bageswar.txt', '/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul')
# Out:
# Data extracted and saved to /content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/KUPKOT [.csv
