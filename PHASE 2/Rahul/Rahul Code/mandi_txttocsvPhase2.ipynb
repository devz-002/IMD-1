# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
input_file_path = '/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/mandi.txt'

# %%
import csv

# %% [markdown]
# THE ONE THAT WORKS

# %%
import csv

def extract_to_csv(input_file_path, output_directory):
    # Open the input file for reading
    with open(input_file_path, 'r') as input_file:
        # Read all lines from the file
        lines = input_file.readlines()

        # Extract station name from line 12 (assuming the name is between ':' and ',')
        station_name = lines[11].split(':')[1].split(',')[0].strip()

        # Extract CSV headings from line 14
        csv_headings = lines[13].split()

        # Extract data from lines 16 to 84
        data_lines = lines[15:147]

        # Create a CSV file with the extracted data
        output_file_path = f'{output_directory}/{station_name}.csv'
        with open(output_file_path, 'w', newline='') as csv_file:
            csv_writer = csv.writer(csv_file)

            # Write the CSV headings
            csv_writer.writerow(['YEAR', 'MN'] + csv_headings[2:])

            # Write the data to the CSV file
            for data_line in data_lines:
                # Split the line into columns
                columns = data_line.split()

                # Write the relevant data to the CSV file
                csv_writer.writerow(columns[:2] + columns[2:])

    print(f"Data extracted and saved to {output_file_path}")

# Replace 'path/to/your/input.txt' with the actual file path
# Replace 'path/to/your/output_directory' with the desired output directory
extract_to_csv('/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/mandi.txt', '/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul')
# Out:
# Data extracted and saved to /content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/BALDWARA.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import csv

def extract_to_csv(input_file_path, output_directory):
    # Open the input file for reading
    with open(input_file_path, 'r') as input_file:
        # Read all lines from the file
        lines = input_file.readlines()

        # Extract station name from line 97 (assuming the name is between ':' and ',')
        station_name = lines[260].split(':')[1].split(',')[0].strip()

        # Extract CSV headings from line 99
        csv_headings = lines[262].split()

        # Extract data from lines 101 to 168
        data_lines = lines[264:360]

        # Create a CSV file with the extracted data
        output_file_path = f'{output_directory}/{station_name}.csv'
        with open(output_file_path, 'w', newline='') as csv_file:
            csv_writer = csv.writer(csv_file)

            # Write the CSV headings
            csv_writer.writerow(['YEAR', 'MN'] + csv_headings[2:])

            # Write the data to the CSV file
            for data_line in data_lines:
                # Split the line into columns
                columns = data_line.split()

                # Write the relevant data to the CSV file
                csv_writer.writerow(columns[:2] + columns[2:])

    print(f"Data extracted and saved to {output_file_path}")

# Replace 'path/to/your/input.txt' with the actual file path
# Replace 'path/to/your/output_directory' with the desired output directory
extract_to_csv('/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/mandi.txt', '/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul')
# Out:
# Data extracted and saved to /content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/BIJAHI [.csv

# %%
import csv

def extract_to_csv(input_file_path, output_directory):
    # Open the input file for reading
    with open(input_file_path, 'r') as input_file:
        # Read all lines from the file
        lines = input_file.readlines()

        # Extract station name from line 97 (assuming the name is between ':' and ',')
        station_name = lines[418].split(':')[1].split(',')[0].strip()

        # Extract CSV headings from line 99
        csv_headings = lines[420].split()

        # Extract data from lines 101 to 168
        data_lines = lines[422:549]

        # Create a CSV file with the extracted data
        output_file_path = f'{output_directory}/{station_name}.csv'
        with open(output_file_path, 'w', newline='') as csv_file:
            csv_writer = csv.writer(csv_file)

            # Write the CSV headings
            csv_writer.writerow(['YEAR', 'MN'] + csv_headings[2:])

            # Write the data to the CSV file
            for data_line in data_lines:
                # Split the line into columns
                columns = data_line.split()

                # Write the relevant data to the CSV file
                csv_writer.writerow(columns[:2] + columns[2:])

    print(f"Data extracted and saved to {output_file_path}")

# Replace 'path/to/your/input.txt' with the actual file path
# Replace 'path/to/your/output_directory' with the desired output directory
extract_to_csv('/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/mandi.txt', '/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul')
# Out:
# Data extracted and saved to /content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/GOHAR [.csv

# %%
import csv

def extract_to_csv(input_file_path, output_directory):
    # Open the input file for reading
    with open(input_file_path, 'r') as input_file:
        # Read all lines from the file
        lines = input_file.readlines()

        # Extract station name from line 97 (assuming the name is between ':' and ',')
        station_name = lines[553].split(':')[1].split(',')[0].strip()

        # Extract CSV headings from line 99
        csv_headings = lines[555].split()

        # Extract data from lines 101 to 168
        data_lines = lines[557:652]

        # Create a CSV file with the extracted data
        output_file_path = f'{output_directory}/{station_name}.csv'
        with open(output_file_path, 'w', newline='') as csv_file:
            csv_writer = csv.writer(csv_file)

            # Write the CSV headings
            csv_writer.writerow(['YEAR', 'MN'] + csv_headings[2:])

            # Write the data to the CSV file
            for data_line in data_lines:
                # Split the line into columns
                columns = data_line.split()

                # Write the relevant data to the CSV file
                csv_writer.writerow(columns[:2] + columns[2:])

    print(f"Data extracted and saved to {output_file_path}")

# Replace 'path/to/your/input.txt' with the actual file path
# Replace 'path/to/your/output_directory' with the desired output directory
extract_to_csv('/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/mandi.txt', '/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul')
# Out:
# Data extracted and saved to /content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/JANJEHLI [.csv

# %%
import csv

def extract_to_csv(input_file_path, output_directory):
    # Open the input file for reading
    with open(input_file_path, 'r') as input_file:
        # Read all lines from the file
        lines = input_file.readlines()

        # Extract station name from line 97 (assuming the name is between ':' and ',')
        station_name = lines[687].split(':')[1].split(',')[0].strip()

        # Extract CSV headings from line 99
        csv_headings = lines[689].split()

        # Extract data from lines 101 to 168
        data_lines = lines[691:823]

        # Create a CSV file with the extracted data
        output_file_path = f'{output_directory}/{station_name}.csv'
        with open(output_file_path, 'w', newline='') as csv_file:
            csv_writer = csv.writer(csv_file)

            # Write the CSV headings
            csv_writer.writerow(['YEAR', 'MN'] + csv_headings[2:])

            # Write the data to the CSV file
            for data_line in data_lines:
                # Split the line into columns
                columns = data_line.split()

                # Write the relevant data to the CSV file
                csv_writer.writerow(columns[:2] + columns[2:])

    print(f"Data extracted and saved to {output_file_path}")

# Replace 'path/to/your/input.txt' with the actual file path
# Replace 'path/to/your/output_directory' with the desired output directory
extract_to_csv('/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/mandi.txt', '/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul')
# Out:
# Data extracted and saved to /content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/JOGINDARNAGAR [.csv

# %%
import csv

def extract_to_csv(input_file_path, output_directory):
    # Open the input file for reading
    with open(input_file_path, 'r') as input_file:
        # Read all lines from the file
        lines = input_file.readlines()

        # Extract station name from line 97 (assuming the name is between ':' and ',')
        station_name = lines[827].split(':')[1].split(',')[0].strip()

        # Extract CSV headings from line 99
        csv_headings = lines[829].split()

        # Extract data from lines 101 to 168
        data_lines = lines[831:963]

        # Create a CSV file with the extracted data
        output_file_path = f'{output_directory}/{station_name}.csv'
        with open(output_file_path, 'w', newline='') as csv_file:
            csv_writer = csv.writer(csv_file)

            # Write the CSV headings
            csv_writer.writerow(['YEAR', 'MN'] + csv_headings[2:])

            # Write the data to the CSV file
            for data_line in data_lines:
                # Split the line into columns
                columns = data_line.split()

                # Write the relevant data to the CSV file
                csv_writer.writerow(columns[:2] + columns[2:])

    print(f"Data extracted and saved to {output_file_path}")

# Replace 'path/to/your/input.txt' with the actual file path
# Replace 'path/to/your/output_directory' with the desired output directory
extract_to_csv('/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/mandi.txt', '/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul')
# Out:
# Data extracted and saved to /content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/KARSOG [.csv

# %%
import csv

def extract_to_csv(input_file_path, output_directory):
    # Open the input file for reading
    with open(input_file_path, 'r') as input_file:
        # Read all lines from the file
        lines = input_file.readlines()

        # Extract station name from line 97 (assuming the name is between ':' and ',')
        station_name = lines[975].split(':')[1].split(',')[0].strip()

        # Extract CSV headings from line 99
        csv_headings = lines[977].split()

        # Extract data from lines 101 to 168
        data_lines = lines[979:1052]

        # Create a CSV file with the extracted data
        output_file_path = f'{output_directory}/{station_name}.csv'
        with open(output_file_path, 'w', newline='') as csv_file:
            csv_writer = csv.writer(csv_file)

            # Write the CSV headings
            csv_writer.writerow(['YEAR', 'MN'] + csv_headings[2:])

            # Write the data to the CSV file
            for data_line in data_lines:
                # Split the line into columns
                columns = data_line.split()

                # Write the relevant data to the CSV file
                csv_writer.writerow(columns[:2] + columns[2:])

    print(f"Data extracted and saved to {output_file_path}")

# Replace 'path/to/your/input.txt' with the actual file path
# Replace 'path/to/your/output_directory' with the desired output directory
extract_to_csv('/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/mandi.txt', '/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul')
# Out:
# Data extracted and saved to /content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/MANDI (AWS) [.csv

# %%
import csv

def extract_to_csv(input_file_path, output_directory):
    # Open the input file for reading
    with open(input_file_path, 'r') as input_file:
        # Read all lines from the file
        lines = input_file.readlines()

        # Extract station name from line 97 (assuming the name is between ':' and ',')
        station_name = lines[1056].split(':')[1].split(',')[0].strip()

        # Extract CSV headings from line 99
        csv_headings = lines[1059].split()

        # Extract data from lines 101 to 168
        data_lines = lines[1061:1132]

        # Create a CSV file with the extracted data
        output_file_path = f'{output_directory}/{station_name}.csv'
        with open(output_file_path, 'w', newline='') as csv_file:
            csv_writer = csv.writer(csv_file)

            # Write the CSV headings
            csv_writer.writerow(['YEAR', 'MN'] + csv_headings[2:])

            # Write the data to the CSV file
            for data_line in data_lines:
                # Split the line into columns
                columns = data_line.split()

                # Write the relevant data to the CSV file
                csv_writer.writerow(columns[:2] + columns[2:])

    print(f"Data extracted and saved to {output_file_path}")

# Replace 'path/to/your/input.txt' with the actual file path
# Replace 'path/to/your/output_directory' with the desired output directory
extract_to_csv('/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/mandi.txt', '/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul')
# Out:
# Data extracted and saved to /content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/MANDI.csv

# %%
import csv

def extract_to_csv(input_file_path, output_directory):
    # Open the input file for reading
    with open(input_file_path, 'r') as input_file:
        # Read all lines from the file
        lines = input_file.readlines()

        # Extract station name from line 97 (assuming the name is between ':' and ',')
        station_name = lines[1136].split(':')[1].split(',')[0].strip()

        # Extract CSV headings from line 99
        csv_headings = lines[1138].split()

        # Extract data from lines 101 to 168
        data_lines = lines[1140:1215]

        # Create a CSV file with the extracted data
        output_file_path = f'{output_directory}/{station_name}.csv'
        with open(output_file_path, 'w', newline='') as csv_file:
            csv_writer = csv.writer(csv_file)

            # Write the CSV headings
            csv_writer.writerow(['YEAR', 'MN'] + csv_headings[2:])

            # Write the data to the CSV file
            for data_line in data_lines:
                # Split the line into columns
                columns = data_line.split()

                # Write the relevant data to the CSV file
                csv_writer.writerow(columns[:2] + columns[2:])

    print(f"Data extracted and saved to {output_file_path}")

# Replace 'path/to/your/input.txt' with the actual file path
# Replace 'path/to/your/output_directory' with the desired output directory
extract_to_csv('/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/mandi.txt', '/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul')
# Out:
# Data extracted and saved to /content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/MANDI SADAR [.csv

# %%
import csv

def extract_to_csv(input_file_path, output_directory):
    # Open the input file for reading
    with open(input_file_path, 'r') as input_file:
        # Read all lines from the file
        lines = input_file.readlines()

        # Extract station name from line 97 (assuming the name is between ':' and ',')
        station_name = lines[1219].split(':')[1].split(',')[0].strip()

        # Extract CSV headings from line 99
        csv_headings = lines[1221].split()

        # Extract data from lines 101 to 168
        data_lines = lines[1223:1350]

        # Create a CSV file with the extracted data
        output_file_path = f'{output_directory}/{station_name}.csv'
        with open(output_file_path, 'w', newline='') as csv_file:
            csv_writer = csv.writer(csv_file)

            # Write the CSV headings
            csv_writer.writerow(['YEAR', 'MN'] + csv_headings[2:])

            # Write the data to the CSV file
            for data_line in data_lines:
                # Split the line into columns
                columns = data_line.split()

                # Write the relevant data to the CSV file
                csv_writer.writerow(columns[:2] + columns[2:])

    print(f"Data extracted and saved to {output_file_path}")

# Replace 'path/to/your/input.txt' with the actual file path
# Replace 'path/to/your/output_directory' with the desired output directory
extract_to_csv('/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/mandi.txt', '/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul')
# Out:
# Data extracted and saved to /content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/PANDOH [.csv

# %%
import csv

def extract_to_csv(input_file_path, output_directory):
    # Open the input file for reading
    with open(input_file_path, 'r') as input_file:
        # Read all lines from the file
        lines = input_file.readlines()

        # Extract station name from line 97 (assuming the name is between ':' and ',')
        station_name = lines[1503].split(':')[1].split(',')[0].strip()

        # Extract CSV headings from line 99
        csv_headings = lines[1505].split()

        # Extract data from lines 101 to 168
        data_lines = lines[1507:1634]

        # Create a CSV file with the extracted data
        output_file_path = f'{output_directory}/{station_name}.csv'
        with open(output_file_path, 'w', newline='') as csv_file:
            csv_writer = csv.writer(csv_file)

            # Write the CSV headings
            csv_writer.writerow(['YEAR', 'MN'] + csv_headings[2:])

            # Write the data to the CSV file
            for data_line in data_lines:
                # Split the line into columns
                columns = data_line.split()

                # Write the relevant data to the CSV file
                csv_writer.writerow(columns[:2] + columns[2:])

    print(f"Data extracted and saved to {output_file_path}")

# Replace 'path/to/your/input.txt' with the actual file path
# Replace 'path/to/your/output_directory' with the desired output directory
extract_to_csv('/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/mandi.txt', '/content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul')
# Out:
# Data extracted and saved to /content/drive/MyDrive/Phase 2-10 DISTRICTS 2012 TO 2023/Rahul/SUNDARNAGAR [.csv
